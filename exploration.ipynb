# %% [markdown]
# # Exploring the prices dataset

# %%
import pandas as pd 

df = pd.read_csv("wfp_food_prices_uga.csv")
df.shape
# Out:
# (25526, 16)

# %%
df.head()
# Out:
#          date   admin1             admin2 market  market_id  latitude  \
# 0  2006-01-15    Busia        Samia-bugwe  Busia       2665      0.47
# 1  2006-01-15  Kampala    Central Kampala  Owino        258      0.32
# 2  2006-01-15     Lira  Lira Municipality   Lira        263      2.23
# 3  2006-02-15    Busia        Samia-bugwe  Busia       2665      0.47
# 4  2006-02-15  Kampala    Central Kampala  Owino        258      0.32
#
#    longitude            category commodity  commodity_id unit priceflag  \
# 0      34.09  cereals and tubers     Maize            51   KG    actual
# 1      32.57  cereals and tubers      Rice            52   KG    actual
# 2      32.91  cereals and tubers     Maize            51   KG    actual
# 3      34.09  cereals and tubers     Maize            51   KG    actual
# 4      32.57  cereals and tubers     Maize            51   KG    actual
#
#    pricetype currency    price  usdprice
# 0  Wholesale      UGX   298.40      0.17
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25526 entries, 0 to 25525
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          25526 non-null  str
#  1   admin1        25526 non-null  str
#  2   admin2        25526 non-null  str
#  3   market        25526 non-null  str
#  4   market_id     25526 non-null  int64
#  5   latitude      25526 non-null  float64
#  6   longitude     25526 non-null  float64
#  7   category      25526 non-null  str
#  8   commodity     25526 non-null  str
#  9   commodity_id  25526 non-null  int64
#  10  unit          25526 non-null  str
#  11  priceflag     25526 non-null  str
#  12  pricetype     25526 non-null  str
#  13  currency      25526 non-null  str
#  14  price         25526 non-null  float64
#  15  usdprice      25526 non-null  float64
# dtypes: float64(4), int64(2), str(10)
# memory usage: 3.1 MB
